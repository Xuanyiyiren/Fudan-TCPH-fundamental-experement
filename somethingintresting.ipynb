# %%
import sympy as sy
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Simhei']  #显示中文
plt.rcParams['axes.unicode_minus']=False    #显示负号  

x,t,tau1,tau2,k=sy.symbols('x t tau1 tau2 k',postive=True)

y=(sy.exp(-t/tau1)-sy.exp(-t/tau2))

t1=1e-1
t2=1e9

# f=t+sy.sin(t)
# sy.plot(f)#绘图结果如下
y.diff(t)
a,=sy.solve(y.diff(t),t)
m=sy.simplify(y.subs(t,a))
y=y/m
display(y)
z=y.subs(tau1,t1).subs(tau2,t2)
# sy.plot(z,(t,min(t1,t2)/10,max(t1,t2)*10))

f = sy.lambdify(t, z, 'numpy')

datax=np.linspace(min(t1,t2)/100,max(t1,t2)*10,1000)

datay=f(datax)
# datay
plt.plot(datax,datay)
# plt.xlim(t1/10,t1*100)
plt.show()


datax=np.linspace(min(t1,t2)/100,max(t1,t2),1000)

datay=f(datax)
# datay
plt.plot(datax,datay)
# plt.xlim(t1/10,t1*100)
plt.show()

datax=np.linspace(min(t1,t2)/100,max(t1,t2)/100,1000)

datay=f(datax)
# datay
plt.plot(datax,datay)
# plt.xlim(t1/10,t1*100)
plt.show()


datax=np.linspace(min(t1,t2)/100,min(t1,t2)*100,1000)

datay=f(datax)
# datay
plt.plot(datax,datay)
# plt.xlim(t1/10,t1*100)
plt.show()

datax=np.linspace(min(t1,t2)/100,min(t1,t2)*10,1000)

datay=f(datax)
# datay
plt.plot(datax,datay)
# plt.xlim(t1/10,t1*100)
plt.show()

datax=np.linspace(min(t1,t2)/100,min(t1,t2),1000)

datay=f(datax)
# datay
plt.plot(datax,datay)
# plt.xlim(t1/10,t1*100)
plt.show()
# Out:
# (-exp(-t/tau2) + exp(-t/tau1))/(-exp(tau1*log(tau2/tau1)/(tau1 - tau2)) + exp(tau2*log(tau2/tau1)/(tau1 - tau2)))

# %%
y=k**(k/(1-k))*(1-k)/(1/sy.exp(sy.exp(k)))
sy.plot(y)
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# d:\anaconda\lib\site-packages\sympy\plotting\plot.py:1618: RuntimeWarning: invalid value encountered in double_scalars
#   cos_theta = dot_product / (vector_a_norm * vector_b_norm)
# d:\anaconda\lib\site-packages\sympy\plotting\plot.py:1469: RuntimeWarning: overflow encountered in double_scalars
#   pos_bottom = ('data', 0) if yl*yh <= 0 else 'center'
# d:\anaconda\lib\site-packages\matplotlib\ticker.py:2073: RuntimeWarning: overflow encountered in multiply
#   steps = self._extended_steps * scale
